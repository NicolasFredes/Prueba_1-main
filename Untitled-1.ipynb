# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()
# Out:
# c:\Users\kazek\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
dataset_ref = client.dataset("covid19_jhu_csse", project="bigquery-public-data")

dataset = client.get_dataset(dataset_ref)

# %%
tables = list(client.list_tables(dataset))

for table in tables:  
    print(table.table_id)
# Out:
# confirmed_cases
# deaths
# recovered_cases
# summary

# %%
confirmados = dataset_ref.table("confirmed_cases")
muertes = dataset_ref.table("deaths")
recuperados = dataset_ref.table("recovered_cases")
resumen = dataset_ref.table("summary")

tabla_confirmados = client.get_table(confirmados)
tabla_muertes = client.get_table(muertes)
tabla_recuperados = client.get_table(recuperados)
tabla_resumen = client.get_table(resumen)

# %%
tabla_resumen.schema
# Out:
# [SchemaField('province_state', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('country_region', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('date', 'DATE', 'NULLABLE', None, None, (), None),
#  SchemaField('latitude', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('longitude', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('location_geom', 'GEOGRAPHY', 'NULLABLE', None, None, (), None),
#  SchemaField('confirmed', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('deaths', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('recovered', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('active', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('fips', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('admin2', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('combined_key', 'STRING', 'NULLABLE', None, None, (), None)]

# %%
client.list_rows(tabla_confirmados, selected_fields =tabla_confirmados.schema[:5] + tabla_confirmados.schema[-3:] , max_results=5).to_dataframe()
# Out:
#   province_or_state country_or_region  latitude  longitude  \
# 0              None        Antarctica  -71.9499     23.347
# 1  Diamond Princess            Canada       0.0        0.0
# 2              None      Korea, North   40.3399   127.5101
# 3              None             Nauru   -0.5228   166.9315
# 4              Niue       New Zealand  -19.0544  -169.8672
#
#                location_geom _3_7_23 _3_8_23 _3_9_23
# 0     POINT(-71.9499 23.347)      11      11      11
# 1             POINT(0.0 0.0)       0       0       0
# 2    POINT(40.3399 127.5101)       1       1       1
# 3    POINT(-0.5228 166.9315)    5247    5247    5247
# 4  POINT(-19.0544 -169.8672)     791     791     792

# %%
client.list_rows(tabla_muertes, selected_fields =tabla_muertes.schema[:5] + tabla_muertes.schema[-3:] , max_results=5).to_dataframe()
# Out:
#        province_or_state country_or_region  latitude  longitude  \
# 0                   None        Antarctica  -71.9499     23.347
# 1     Northern Territory         Australia  -12.4634   130.8456
# 2         Grand Princess            Canada       0.0        0.0
# 3  Northwest Territories            Canada   64.8255  -124.8457
# 4   Prince Edward Island            Canada   46.5107   -63.4168
#
#               location_geom _3_7_23 _3_8_23 _3_9_23
# 0    POINT(-71.9499 23.347)       0       0       0
# 1  POINT(-12.4634 130.8456)      90      90      91
# 2            POINT(0.0 0.0)       0       0       0
# 3  POINT(64.8255 -124.8457)      22      22      22
# 4   POINT(46.5107 -63.4168)      93      93      93

# %%
client.list_rows(tabla_recuperados, selected_fields =tabla_recuperados.schema[:5] + tabla_recuperados.schema[-3:] , max_results=5).to_dataframe()
# Out:
#   province_or_state country_or_region  latitude longitude  \
# 0              None        Antarctica  -71.9499    23.347
# 1           Unknown             China      None      None
# 2              None          Kiribati   -3.3704  -168.734
# 3              None      Korea, North   40.3399  127.5101
# 4              None             Nauru   -0.5228  166.9315
#
#              location_geom _3_7_23 _3_8_23 _3_9_23
# 0   POINT(-71.9499 23.347)       0       0       0
# 1           POINT(nan nan)       0       0       0
# 2  POINT(-3.3704 -168.734)       0       0       0
# 3  POINT(40.3399 127.5101)       0       0       0
# 4  POINT(-0.5228 166.9315)       0       0       0

# %%
client.list_rows(tabla_resumen, max_results=5, selected_fields =tabla_resumen.schema[0:3] + tabla_resumen.schema[6:10]).to_dataframe()
# Out:
#    province_state country_region        date  confirmed  deaths recovered  \
# 0    South Dakota             US  2020-05-15          8       0         0
# 1  South Carolina             US  2020-05-15        501      10         0
# 2        Michigan             US  2020-05-15         13       1         0
# 3         Florida             US  2020-05-15        367      40         0
# 4        Virginia             US  2020-05-15         11       0         0
#
#    active
# 0       8
# 1     491
# 2      12
# 3     327
# 4      11

# %%
import matplotlib.pyplot as plt

# %%
query = """
    SELECT country_region, MAX(deaths) AS max_deaths
    FROM `bigquery-public-data.covid19_jhu_csse.summary`
    GROUP BY country_region
    ORDER BY country_region ASC
"""
rows = client.query(query).to_dataframe()

# %%
rows = rows.dropna()
paises = rows['country_region'].tolist()
muertes = rows['max_deaths'].tolist()

# %%
plt.figure(figsize=(20, 6))
plt.plot(paises, muertes, marker='o', linestyle='-')
plt.title('Máximo de Muertes por COVID-19')
plt.xlabel('País')
plt.ylabel('Muertes')
plt.xticks(rotation=90, fontsize=4)
plt.grid(True, axis='y', linestyle='-', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
query = """
    SELECT country_region, MAX(confirmed) AS max_confirmed
    FROM `bigquery-public-data.covid19_jhu_csse.summary`
    GROUP BY country_region
    ORDER BY country_region ASC
"""
rows = client.query(query).to_dataframe()

# %%
rows = rows.dropna()
paises = rows['country_region'].tolist()
confirmados = rows['max_confirmed'].tolist()

# %%
plt.figure(figsize=(20, 6))
plt.plot(paises, confirmados, marker='o', linestyle='-')
plt.title('Máximo de Casos confirmados de COVID-19')
plt.xlabel('País')
plt.ylabel('Casos')
plt.xticks(rotation=90, fontsize=4)
plt.grid(True, axis='y', linestyle='-', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
query = """
    SELECT country_region, max_recovered
    FROM (
        SELECT country_region, MAX(CAST(recovered AS INT64)) AS max_recovered
        FROM `bigquery-public-data.covid19_jhu_csse.summary`
        GROUP BY country_region
        ORDER BY country_region ASC
    )
"""
rows = client.query(query).to_dataframe()

# %%
rows = rows.dropna()
paises = rows['country_region'].tolist()
recuperados = rows['max_recovered'].tolist()

# %%
plt.figure(figsize=(20, 6))
plt.plot(paises, recuperados, marker='o', linestyle='-')
plt.title('Máximo de Casos confirmados de COVID-19')
plt.xlabel('País')
plt.ylabel('Casos')
plt.xticks(rotation=90, fontsize=4)
plt.grid(True, axis='y', linestyle='-', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
query = """
    SELECT country_region, MAX(active) AS max_active
    FROM `bigquery-public-data.covid19_jhu_csse.summary`
    GROUP BY country_region
    ORDER BY country_region ASC
"""
rows = client.query(query).to_dataframe()

# %%
rows = rows.dropna()

paises = rows['country_region'].tolist()
activos = rows['max_active'].tolist()

# %%
plt.figure(figsize=(20, 6))
plt.plot(paises, activos, marker='o', linestyle='-')
plt.title('Máximo de Casos activos COVID-19 (hasta septiembre 2023)')
plt.xlabel('País')
plt.ylabel('Casos Activos')
plt.xticks(rotation=90, fontsize=4)
plt.grid(True, axis='y', linestyle='-', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
query = """
    SELECT country_region, SUM(confirmed) AS casos_confirmados
    FROM `bigquery-public-data.covid19_jhu_csse.summary`
    WHERE country_region IN ('Chile', 'US')
    GROUP BY country_region
"""
rows = client.query(query).to_dataframe()

# %%
result = client.query(query).to_dataframe()

# %%
plt.figure(figsize=(8, 6))
plt.bar(result['country_region'], result['casos_confirmados'], color=['blue', 'red'])
plt.xlabel('País')
plt.ylabel('Casos Confirmados')
plt.title('Casos Confirmados de COVID-19 en Chile y Estados Unidos')
plt.grid(True, axis='y', linestyle='-', linewidth=0.5)
plt.show()
